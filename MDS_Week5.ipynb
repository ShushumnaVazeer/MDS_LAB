# %% [markdown]
# <a href="https://colab.research.google.com/github/ShushumnaVazeer/MDS_LAB/blob/main/MDS_Week5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Import CSV file
df = pd.read_csv("/content/iris.csv")

print("Original Dataset:")
print(df.head())

# Detect missing values
print("\nMissing Values:")
print(df.isnull().sum())

# Drop rows containing missing values
df_dropped = df.dropna()

print("\nAfter Dropping Missing Values:")
print(df_dropped.head())

# Fill missing numeric values with column mean
df_filled = df.copy()

numeric_columns = df_filled.select_dtypes(include="number").columns

for col in numeric_columns:
    df_filled[col] = df_filled[col].fillna(df_filled[col].mean())

print("\nAfter Filling Missing Values:")
print(df_filled.head())
# Out:
# Original Dataset:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
#
# Missing Values:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64
#
# After Dropping Missing Values:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
#
# ...

# %%
import pandas as pd

# Import CSV file
df = pd.read_csv("/content/iris.csv")

# Select numeric columns
columns = ["sepal_length", "sepal_width", "petal_length", "petal_width"]

# Calculate Q1 and Q3
Q1 = df[columns].quantile(0.25)
Q3 = df[columns].quantile(0.75)

# Calculate IQR
IQR = Q3 - Q1

# Detect outliers
outliers = df[
    ((df[columns] < (Q1 - 1.5 * IQR)) |
     (df[columns] > (Q3 + 1.5 * IQR))).any(axis=1)
]

print("Outliers:")
print(outliers)

# Filter outliers
df_filtered = df[
    ~((df[columns] < (Q1 - 1.5 * IQR)) |
      (df[columns] > (Q3 + 1.5 * IQR))).any(axis=1)
]

print("\nDataset after removing outliers:")
print(df_filtered)
# Out:
# Outliers:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 15           5.7          4.4           1.5          0.4      setosa
# 32           5.2          4.1           1.5          0.1      setosa
# 33           5.5          4.2           1.4          0.2      setosa
# 60           5.0          2.0           3.5          1.0  versicolor
#
# Dataset after removing outliers:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# ...

# %%
print(df.shape)
# Out:
# (150, 5)
